# %%
import pandas as pd

# %%
import requests
from io import StringIO

url = ""
s = requests.get(url).content
f = s.decode('utf-8')
d = StringIO(f)
c = pd.read_csv(d)
# Out:
# ---------------------------------------------------------------------------
# MissingSchema                             Traceback (most recent call last)
# Cell In[3], line 5
#       2 from io import StringIO
#       4 url = ""
# ----> 5 s = requests.get(url).content
#       6 f = s.decode('utf-8')
#       7 d = StringIO(f)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
# ...

# %%
pd.read_csv('x.tsv', sep = '\t', name = [1,2,3,4])

# %%
pd.read_csv('Sales_April_2019.csv', index_col = 'Order ID')
# Out:
#                              Product Quantity Ordered Price Each  \
# Order ID
# 176558          USB-C Charging Cable                2      11.95
# NaN                              NaN              NaN        NaN
# 176559    Bose SoundSport Headphones                1      99.99
# 176560                  Google Phone                1        600
# 176560              Wired Headphones                1      11.99
# ...                              ...              ...        ...
# 194090                  Google Phone                1        600
# 194091         AA Batteries (4-pack)                1       3.84
# 194092        AAA Batteries (4-pack)                2       2.99
# 194093         AA Batteries (4-pack)                1       3.84
# 194094      Lightning Charging Cable                1      14.95
#
#               Order Date                        Purchase Address
# Order ID
# 176558    04/19/19 08:46            917 1st St, Dallas, TX 75001
# ...

# %%
pd.read_csv ('Sales_April_2019.csv' , header =1)
pd.read_csv ('Sales_April_2019.csv' , usecols = ['Product','Order Date'])
# Out:
#                           Product      Order Date
# 0            USB-C Charging Cable  04/19/19 08:46
# 1                             NaN             NaN
# 2      Bose SoundSport Headphones  04/07/19 22:30
# 3                    Google Phone  04/12/19 14:38
# 4                Wired Headphones  04/12/19 14:38
# ...                           ...             ...
# 18378                Google Phone  04/08/19 17:11
# 18379       AA Batteries (4-pack)  04/15/19 16:02
# 18380      AAA Batteries (4-pack)  04/28/19 14:36
# 18381       AA Batteries (4-pack)  04/14/19 15:09
# 18382    Lightning Charging Cable  04/18/19 11:08
#
# [18383 rows x 2 columns]

# %%
pd.read_csv('Sales_April_2019.csv', skiprows= [1, 5])
pd.read_csv('Sales_April_2019.csv', nrows = 100)
# Out:
#     Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558.0        USB-C Charging Cable               2.0       11.95
# 1        NaN                         NaN               NaN         NaN
# 2   176559.0  Bose SoundSport Headphones               1.0       99.99
# 3   176560.0                Google Phone               1.0      600.00
# 4   176560.0            Wired Headphones               1.0       11.99
# ..       ...                         ...               ...         ...
# 95  176648.0            27in FHD Monitor               1.0      149.99
# 96  176649.0        USB-C Charging Cable               1.0       11.95
# 97  176650.0    Lightning Charging Cable               1.0       14.95
# 98  176651.0                      iPhone               1.0      700.00
# 99  176652.0          LG Washing Machine               1.0      600.00
#
#         Order Date                      Purchase Address
# 0   04/19/19 08:46          917 1st St, Dallas, TX 75001
# ...

# %%
pd.read_csv('Sales_April_2019.csv', encoding = 'latin-1', error_bad_lines = False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 pd.read_csv('Sales_April_2019.csv', encoding = 'latin-1', error_bad_lines = False)
#
# TypeError: read_csv() got an unexpected keyword argument 'error_bad_lines'. Did you mean 'on_bad_lines'?

# %%
pd.read_csv('Sales_April_2019.csv', dtype = {'target': int}).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18383 entries, 0 to 18382
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          18324 non-null  object
#  1   Product           18324 non-null  object
#  2   Quantity Ordered  18324 non-null  object
#  3   Price Each        18324 non-null  object
#  4   Order Date        18324 non-null  object
#  5   Purchase Address  18324 non-null  object
# dtypes: object(6)
# memory usage: 861.8+ KB

# %%
pd.read_csv('Sales_April_2019.csv', parse_dates = ['Order Date']).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18383 entries, 0 to 18382
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          18324 non-null  object
#  1   Product           18324 non-null  object
#  2   Quantity Ordered  18324 non-null  object
#  3   Price Each        18324 non-null  object
#  4   Order Date        18324 non-null  object
#  5   Purchase Address  18324 non-null  object
# dtypes: object(6)
# memory usage: 861.8+ KB
# C:\Users\savitar\AppData\Local\Temp\ipykernel_8796\4185748344.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.read_csv('Sales_April_2019.csv', parse_dates = ['Order Date']).info()

# %%
dfs = pd.read_csv ('Sales_April_2019.csv' ,chunksize = 5000 )
for i in dfs:
    print(i.shape)
# Out:
# (5000, 6)
# (5000, 6)
# (5000, 6)
# (3383, 6)

# %%
def rename(name):
    if name == 1.0:
        print('True')
    else:
        return name

pd.read_csv ('Sales_April_2019.csv' , converters = {'Quantity Orderd': rename} )
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 1          NaN                         NaN              NaN        NaN
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 18378   194090                Google Phone                1        600
# 18379   194091       AA Batteries (4-pack)                1       3.84
# 18380   194092      AAA Batteries (4-pack)                2       2.99
# 18381   194093       AA Batteries (4-pack)                1       3.84
# 18382   194094    Lightning Charging Cable                1      14.95
#
#            Order Date                        Purchase Address
# ...
